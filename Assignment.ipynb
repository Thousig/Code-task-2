# %%
#importer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import *
import sklearn.model_selection as ms
import sklearn.linear_model as lm
#importer data
filepath = "HR_data.csv"
data = pd.read_csv(filepath, sep = ',')
data
# Out:
#      Unnamed: 0    HR_Mean  HR_Median     HR_std  HR_Min  HR_Max     HR_AUC  \
# 0             0  77.965186     78.000   3.345290   73.23   83.37  22924.945
# 1             1  70.981097     70.570   2.517879   67.12   78.22  21930.400
# 2             2  73.371959     73.360   3.259569   67.88   80.22  21647.085
# 3             3  78.916822     77.880   4.054595   72.32   84.92  25258.905
# 4             4  77.322226     74.550   6.047603   70.52   90.15  23890.565
# ..          ...        ...        ...        ...     ...     ...        ...
# 163         163  73.594539     72.380   9.474556   57.43   93.53  21482.985
# 164         164  57.839897     54.130   6.796647   52.97   74.14  16825.740
# 165         165  64.237295     65.195   3.589241   58.97   72.63  18691.065
# 166         166  70.834320     70.440   2.391160   66.65   76.07  20753.005
# 167         167  71.133878     69.225  14.069337   57.17  114.33  20820.320
#
# ...

# %%
#importer data
filepath = "HR_data.csv"
data = pd.read_csv(filepath, sep = ',')
data
# Out:
#      Unnamed: 0    HR_Mean  HR_Median     HR_std  HR_Min  HR_Max     HR_AUC  \
# 0             0  77.965186     78.000   3.345290   73.23   83.37  22924.945
# 1             1  70.981097     70.570   2.517879   67.12   78.22  21930.400
# 2             2  73.371959     73.360   3.259569   67.88   80.22  21647.085
# 3             3  78.916822     77.880   4.054595   72.32   84.92  25258.905
# 4             4  77.322226     74.550   6.047603   70.52   90.15  23890.565
# ..          ...        ...        ...        ...     ...     ...        ...
# 163         163  73.594539     72.380   9.474556   57.43   93.53  21482.985
# 164         164  57.839897     54.130   6.796647   52.97   74.14  16825.740
# 165         165  64.237295     65.195   3.589241   58.97   72.63  18691.065
# 166         166  70.834320     70.440   2.391160   66.65   76.07  20753.005
# 167         167  71.133878     69.225  14.069337   57.17  114.33  20820.320
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is already loaded into a DataFrame named 'data'
# If 'frustrated' is a feature/column in your dataset

# Get list of all columns including 'frustrated'
features = data.columns

# Create subplots for each feature
fig, axs = plt.subplots(nrows=len(features), figsize=(10, 20))

# Plot histograms for each feature
for i, feature in enumerate(features):
    axs[i].hist(data[feature], bins=20, edgecolor='black', alpha=0.7)
    axs[i].set_title(f'Distribution of {feature}')
    axs[i].set_xlabel(feature)
    axs[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is already loaded into a DataFrame named 'data'
# If 'frustrated' is a feature/column in your dataset

# Get list of all columns including 'frustrated'
features = data.columns

# Define the number of columns for subplots (2 in this case)
num_cols = 2
# Calculate the number of rows needed for subplots
num_rows = (len(features) + num_cols - 1) // num_cols

# Create subplots with specified size and layout
fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 8))

# Flatten the axs array to iterate over all subplots
axs = axs.flatten()

# Plot histograms for each feature
for i, feature in enumerate(features):
    axs[i].hist(data[feature], bins=20, edgecolor='black', alpha=0.7)
    axs[i].set_title(f'Distribution of {feature}')
    axs[i].set_xlabel(feature)
    axs[i].set_ylabel('Frequency')

# Hide any unused subplots
for j in range(i + 1, num_rows * num_cols):
    axs[j].axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is already loaded into a DataFrame named 'data'
# If 'frustrated' is a feature/column in your dataset

# Get list of all columns including 'frustrated'
features = data.columns

# Define the number of columns for subplots (2 in this case)
num_cols = 2
# Calculate the number of rows needed for subplots
num_rows = (len(features) - 1 + num_cols - 1) // num_cols

# Create subplots with specified size and layout
fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 8))

# Flatten the axs array to iterate over all subplots
axs = axs.flatten()

# Start from the second feature to leave out the first one
for i, feature in enumerate(features[1:], 1):
    row = (i - 1) // num_cols
    col = (i - 1) % num_cols
    axs[i - 1].hist(data[feature], bins=20, edgecolor='black', alpha=0.7)
    axs[i - 1].set_title(f'Distribution of {feature}')
    axs[i - 1].set_xlabel(feature)
    axs[i - 1].set_ylabel('Frequency')

# Hide any unused subplots
for j in range(len(features) - 1, num_rows * num_cols):
    axs[j].axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is already loaded into a DataFrame named 'data'
# If 'frustrated' is a feature/column in your dataset

# Get list of all columns including 'frustrated'
features = data.columns

# Define the number of columns for subplots (2 in this case)
num_cols = 2
# Calculate the number of rows needed for subplots
num_rows = (len(features) - 7 + num_cols - 1) // num_cols  # Excluding last six and frustrated

# Create subplots with specified size and layout
fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 8))

# Flatten the axs array to iterate over all subplots
axs = axs.flatten()

# Start from the second feature to leave out the first one and the last six (excluding 'frustrated')
for i, feature in enumerate(features[1:-6], 1):
    row = (i - 1) // num_cols
    col = (i - 1) % num_cols
    axs[i - 1].hist(data[feature], bins=20, edgecolor='black', alpha=0.7)
    axs[i - 1].set_title(f'Distribution of {feature}')
    axs[i - 1].set_xlabel(feature)
    axs[i - 1].set_ylabel('Frequency')

# Hide any unused subplots
for j in range(len(features) - 7, num_rows * num_cols):
    axs[j].axis('off')

plt.tight_layout()
plt.show()

# %%
#splitter dataen så unnamed blir droppet
data = data.drop('Unnamed: 0', axis = 1)

# %%
data
# Out:
#        HR_Mean  HR_Median     HR_std  HR_Min  HR_Max     HR_AUC    Round  \
# 0    77.965186     78.000   3.345290   73.23   83.37  22924.945  round_3
# 1    70.981097     70.570   2.517879   67.12   78.22  21930.400  round_3
# 2    73.371959     73.360   3.259569   67.88   80.22  21647.085  round_3
# 3    78.916822     77.880   4.054595   72.32   84.92  25258.905  round_2
# 4    77.322226     74.550   6.047603   70.52   90.15  23890.565  round_2
# ..         ...        ...        ...     ...     ...        ...      ...
# 163  73.594539     72.380   9.474556   57.43   93.53  21482.985  round_4
# 164  57.839897     54.130   6.796647   52.97   74.14  16825.740  round_4
# 165  64.237295     65.195   3.589241   58.97   72.63  18691.065  round_1
# 166  70.834320     70.440   2.391160   66.65   76.07  20753.005  round_1
# 167  71.133878     69.225  14.069337   57.17  114.33  20820.320  round_1
#
#       Phase  Individual  Puzzler  Frustrated Cohort
# ...

# %%
#jeg plotter en normalfordeling over dataen
plt.hist(data['HR_Mean'], bins = 20, density = True)
# Out:
# (array([0.00613365, 0.00920047, 0.00613365, 0.00920047, 0.0122673 ,
#         0.03373507, 0.05213602, 0.05826966, 0.05213602, 0.05213602,
#         0.05520284, 0.04600237, 0.03066824, 0.02760142, 0.01840095,
#         0.00613365, 0.0122673 , 0.00920047, 0.01533412, 0.00306682]),
#  array([57.34146259, 59.28235652, 61.22325046, 63.16414439, 65.10503833,
#         67.04593227, 68.9868262 , 70.92772014, 72.86861408, 74.80950801,
#         76.75040195, 78.69129589, 80.63218982, 82.57308376, 84.5139777 ,
#         86.45487163, 88.39576557, 90.33665951, 92.27755344, 94.21844738,
#         96.15934132]),
#  <BarContainer object of 20 artists>)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer
label = LabelEncoder()
binarizer = LabelBinarizer()
data['Cohort'] = label.fit_transform(data['Cohort'])
data['Phase'] = label.fit_transform(data['Phase'])
data['Round'] = label.fit_transform(data['Round'])
data['Frustrated'] = data['Frustrated'].apply(lambda x: 1 if x >= 4 else 0)
data
# Out:
#        HR_Mean  HR_Median     HR_std  HR_Min  HR_Max     HR_AUC  Round  Phase  \
# 0    77.965186     78.000   3.345290   73.23   83.37  22924.945      2      2
# 1    70.981097     70.570   2.517879   67.12   78.22  21930.400      2      1
# 2    73.371959     73.360   3.259569   67.88   80.22  21647.085      2      0
# 3    78.916822     77.880   4.054595   72.32   84.92  25258.905      1      2
# 4    77.322226     74.550   6.047603   70.52   90.15  23890.565      1      1
# ..         ...        ...        ...     ...     ...        ...    ...    ...
# 163  73.594539     72.380   9.474556   57.43   93.53  21482.985      3      1
# 164  57.839897     54.130   6.796647   52.97   74.14  16825.740      3      0
# 165  64.237295     65.195   3.589241   58.97   72.63  18691.065      0      2
# 166  70.834320     70.440   2.391160   66.65   76.07  20753.005      0      1
# 167  71.133878     69.225  14.069337   57.17  114.33  20820.320      0      0
#
# ...

# %%
#plot the HR_std log transformed
plt.hist(np.log(data['HR_std']), bins = 20, density = True)
# Out:
# (array([0.03657503, 0.        , 0.07315005, 0.07315005, 0.10972508,
#         0.32917524, 0.47547535, 0.47547535, 0.62177546, 0.54862541,
#         0.65835049, 0.4023253 , 0.65835049, 0.51205038, 0.18287514,
#         0.25602519, 0.14630011, 0.32917524, 0.14630011, 0.10972508]),
#  array([-0.16930105, -0.00655665,  0.15618775,  0.31893216,  0.48167656,
#          0.64442096,  0.80716536,  0.96990977,  1.13265417,  1.29539857,
#          1.45814298,  1.62088738,  1.78363178,  1.94637619,  2.10912059,
#          2.27186499,  2.4346094 ,  2.5973538 ,  2.7600982 ,  2.92284261,
#          3.08558701]),
#  <BarContainer object of 20 artists>)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is already loaded into a DataFrame named 'data'
# If 'frustrated' is a feature/column in your dataset

# Get list of all columns including 'frustrated'
features = data.columns

# Define the number of columns for subplots (2 in this case)
num_cols = 2
# Calculate the number of rows needed for subplots
num_rows = (len(features) - 7 + num_cols - 1) // num_cols  # Excluding last six and frustrated

# Create subplots with specified size and layout
fig, axs = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 8))

# Flatten the axs array to iterate over all subplots
axs = axs.flatten()

# Start from the second feature to leave out the first one and the last six (excluding 'frustrated')
for i, feature in enumerate(features[1:-6], 1):
    row = (i - 1) // num_cols
    col = (i - 1) % num_cols
    axs[i - 1].hist(data[feature], bins=20, edgecolor='black', alpha=0.7)
    axs[i - 1].set_title(f'Distribution of {feature}')
    axs[i - 1].set_xlabel(feature)
    axs[i - 1].set_ylabel('Frequency')

# Hide any unused subplots
for j in range(len(features) - 7, num_rows * num_cols):
    axs[j].axis('off')

plt.tight_layout()
plt.show()

# %%
#plot the HR_AUC log transformed
plt.hist(np.log(data['HR_AUC']), bins = 20, density = True)
data['HR_AUC'] = np.log(data['HR_AUC'])
data
# Out:
#        HR_Mean  HR_Median     HR_std  HR_Min  HR_Max     HR_AUC  Round  Phase  \
# 0    77.965186     78.000   3.345290   73.23   83.37  10.039981      2      2
# 1    70.981097     70.570   2.517879   67.12   78.22   9.995629      2      1
# 2    73.371959     73.360   3.259569   67.88   80.22   9.982626      2      0
# 3    78.916822     77.880   4.054595   72.32   84.92  10.136934      1      2
# 4    77.322226     74.550   6.047603   70.52   90.15  10.081239      1      1
# ..         ...        ...        ...     ...     ...        ...    ...    ...
# 163  73.594539     72.380   9.474556   57.43   93.53   9.975017      3      1
# 164  57.839897     54.130   6.796647   52.97   74.14   9.730665      3      0
# 165  64.237295     65.195   3.589241   58.97   72.63   9.835801      0      2
# 166  70.834320     70.440   2.391160   66.65   76.07   9.940446      0      1
# 167  71.133878     69.225  14.069337   57.17  114.33   9.943685      0      0
#
# ...

# %%
#plot the HR_Max log transformed
plt.hist(np.log(data['HR_Max']), bins = 20, density = True)
data['HR_AUC'] = np.log(data['HR_AUC'])
data['HR_Max'] = np.log(data['HR_Max'])
data['HR_std'] = np.log(data['HR_std'])

# %%
#plot the HR_std log transformed
plt.hist(np.log(data['HR_std']), bins = 20, density = True)
data['HR_std'] = np.log(data['HR_std'])

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from statsmodels.stats.contingency_tables import cochrans_q, mcnemar
from sklearn.preprocessing import StandardScaler, LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming X_scaled and Y are your feature matrix and labels
# Load data
filepath = "HR_data.csv"
data = pd.read_csv(filepath, sep=',')

# Encode categorical variables if necessary (assuming they are already numeric in your case)
label = LabelEncoder()
data['Cohort'] = label.fit_transform(data['Cohort'])
data['Phase'] = label.fit_transform(data['Phase'])
data['Round'] = label.fit_transform(data['Round'])
data['Frustrated'] = data['Frustrated'].apply(lambda x: 1 if x >= 3 else 0)

#data['HR_AUC'] = np.log(data['HR_AUC'])
#data['HR_Max'] = np.log(data['HR_Max'])
#data['HR_std'] = np.log(data['HR_std'])

# Split data into X (features) and Y (target)
Y = data['Frustrated']
X = data.drop('Frustrated', axis=1)

# Initialize StandardScaler
scaler = StandardScaler()

# Standardize the features
X_scaled = scaler.fit_transform(X)

# Initialize models
log_model = LogisticRegression(max_iter=10000, random_state=1)
rf_model = RandomForestClassifier(random_state=1)
neural_network = MLPClassifier(hidden_layer_sizes=(4, 4,4), max_iter=10000)

# Perform 5-fold stratified cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=1)

# Storage for predictions
preds_log = np.zeros_like(Y)
preds_rf = np.zeros_like(Y)
preds_nn = np.zeros_like(Y)

for train_index, test_index in cv.split(X_scaled, Y):
    # Train and predict with logistic regression
    log_model.fit(X_scaled[train_index], Y[train_index])
    preds_log[test_index] = log_model.predict(X_scaled[test_index])
    
    # Train and predict with random forest
    rf_model.fit(X_scaled[train_index], Y[train_index])
    preds_rf[test_index] = rf_model.predict(X_scaled[test_index])
    
    # Train and predict with neural network
    neural_network.fit(X_scaled[train_index], Y[train_index])
    preds_nn[test_index] = neural_network.predict(X_scaled[test_index])

# Calculate accuracy for each model
accuracy_log = accuracy_score(Y, preds_log)
accuracy_rf = accuracy_score(Y, preds_rf)
accuracy_nn = accuracy_score(Y, preds_nn)

print(f'Accuracy of Logistic Regression: {accuracy_log}')
print(f'Accuracy of Random Forest: {accuracy_rf}')
print(f'Accuracy of Neural Network: {accuracy_nn}')

# Generate confusion matrices for each model
cm_log = confusion_matrix(Y, preds_log)
cm_rf = confusion_matrix(Y, preds_rf)
cm_nn = confusion_matrix(Y, preds_nn)

# Plot confusion matrices
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.heatmap(cm_log, annot=True, fmt='d', cmap='Blues', ax=axes[0])
axes[0].set_title('Confusion Matrix for Logistic Regression')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Greens', ax=axes[1])
axes[1].set_title('Confusion Matrix for Random Forest')
axes[1].set_xlabel('Predicted')
axes[1].set_ylabel('Actual')

sns.heatmap(cm_nn, annot=True, fmt='d', cmap='Reds', ax=axes[2])
axes[2].set_title('Confusion Matrix for Neural Network')
axes[2].set_xlabel('Predicted')
axes[2].set_ylabel('Actual')

plt.tight_layout()
plt.show()

# Prepare data for Cochran's Q test
# Each row corresponds to a sample, and each column corresponds to a model
data = np.column_stack((Y, preds_log, preds_rf, preds_nn))

# Convert data to binary matrix (1 if prediction is correct, 0 otherwise)
correct_log = (data[:, 1] == data[:, 0]).astype(int)
correct_rf = (data[:, 2] == data[:, 0]).astype(int)
correct_nn = (data[:, 3] == data[:, 0]).astype(int)

# Combine the correct predictions
binary_matrix = np.column_stack((correct_log, correct_rf, correct_nn))

# Perform Cochran's Q test
q_result = cochrans_q(binary_matrix)
print(f'Cochran\'s Q statistic: {q_result.statistic}, p-value: {q_result.pvalue}')

# Interpret Cochran's Q test result
alpha = 0.05
if q_result.pvalue < alpha:
    print("Significant difference between the models (reject H0)")
else:
    print("No significant difference between the models (fail to reject H0)")

# Perform pairwise McNemar tests
def perform_mcnemar_test(preds_1, preds_2, labels):
    correct_1 = (preds_1 == labels).astype(int)
    correct_2 = (preds_2 == labels).astype(int)
    
    # Create contingency table
    table = np.zeros((2, 2))
    table[0, 0] = np.sum((correct_1 == 1) & (correct_2 == 1))
    table[0, 1] = np.sum((correct_1 == 1) & (correct_2 == 0))
    table[1, 0] = np.sum((correct_1 == 0) & (correct_2 == 1))
    table[1, 1] = np.sum((correct_1 == 0) & (correct_2 == 0))
    
    result = mcnemar(table, exact=True)
    return result.statistic, result.pvalue

# Logistic Regression vs Random Forest
statistic, pvalue = perform_mcnemar_test(preds_log, preds_rf, Y)
print(f'McNemar test between Logistic Regression and Random Forest: statistic={statistic}, p-value={pvalue}')

# Logistic Regression vs Neural Network
statistic, pvalue = perform_mcnemar_test(preds_log, preds_nn, Y)
print(f'McNemar test between Logistic Regression and Neural Network: statistic={statistic}, p-value={pvalue}')

# Random Forest vs Neural Network
statistic, pvalue = perform_mcnemar_test(preds_rf, preds_nn, Y)
print(f'McNemar test between Random Forest and Neural Network: statistic={statistic}, p-value={pvalue}')
# Out:
# Accuracy of Logistic Regression: 0.625
# Accuracy of Random Forest: 0.7321428571428571
# Accuracy of Neural Network: 0.6130952380952381
# Cochran's Q statistic: 11.2, p-value: 0.0036978637164829338
# Significant difference between the models (reject H0)
# McNemar test between Logistic Regression and Random Forest: statistic=11.0, p-value=0.006426576095691416
# McNemar test between Logistic Regression and Neural Network: statistic=23.0, p-value=0.8854334972865135
# McNemar test between Random Forest and Neural Network: statistic=11.0, p-value=0.002887247974285856

# %%
import matplotlib.pyplot as plt

# Create a bar chart
models = ['Logistic Regression', 'Random Forest', 'Neural Network']
accuracies = [accuracy_log, accuracy_rf, accuracy_nn]

plt.figure(figsize=(10, 6))
plt.bar(models, accuracies, color=['blue', 'green', 'red'])
plt.ylim([0, 1])  # Set y-axis limit to range from 0 to 1
plt.ylabel('Mean cross-validation accuracy')
plt.title('Model Accuracy Comparison')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
tests = ['Cochran\'s Q', 'Logistic vs Random Forest', 'Logistic vs Neural Network', 'Random Forest vs Neural Network']
p_values = [0.01723856833159134, 0.04355852192384191, 0.6587380770236564, 0.009559878856634896]
significance = ['Yes', 'No', 'No', 'Yes']

# Create the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Bar plot for p-values
bar_width = 0.5
bars = ax.bar(tests, p_values, bar_width, color='skyblue', edgecolor='black')

# Annotate the bars with p-values
for bar, p_value, sig in zip(bars, p_values, significance):
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2.0, yval, f'p = {p_value:.3f}\nSig: {sig}', ha='center', va='bottom', fontsize=10, color='black')

# Customize the plot
ax.axhline(y=0.05, color='red', linestyle='--')  # Significance threshold line at p = 0.05
ax.text(len(tests) - 0.5, 0.05, 'Significance threshold (p = 0.05)', ha='center', va='bottom', fontsize=10, color='red')

# Customize the plot
ax.axhline(y=0.0167, color='Orange', linestyle='--')  # Significance threshold line at p = 0.05
ax.text(len(tests) - 0.167, 0.0167, 'Bonferroni corrected significance threshold (p = 0.0167)', ha='center', va='bottom', fontsize=10, color='orange')

ax.set_ylim([0, max(p_values) + 0.1])
ax.set_ylabel('p-value')
ax.set_title('Comparison of Models using Cochran\'s Q and McNemar Tests')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
